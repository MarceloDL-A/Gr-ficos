# %% [markdown]
# [DadosAbertosBrasil](https://www.gustavofurtado.com/DadosAbertosBrasil/_ibge/misc.html)
#
# [Folium](https://medium.com/datasciencearth/map-visualization-with-folium-d1403771717)
#
# [Folium and Geopandas: FeatureGroup for categorial data](https://www.riannek.de/2022/folium-featuregroup-categorial-data/)

# %%
from DadosAbertosBrasil import ibge
import pandas as pd

# %%
df_localidades = ibge.localidades()

# %%
df_coordenadas = ibge.coordenadas()

# %%
df_LATLONG = df_coordenadas[['NM_MUNICIPIO', 'LONG', 'LAT']]

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
df = df_LATLONG.sample(n=100)

# %% [markdown]
# # Exemplo 1 de Folium

# %%
mapc = folium.Map(location=[df_LATLONG.LAT.mean(), df_LATLONG.LONG.mean()], zoom_start=5, control_scale=True)


# Cria camadas
layer1 = folium.FeatureGroup(name='Markers', control=True)

for index, location_info in df.iterrows():

    # Adiciona propriedades às camadas
    layer1.add_child(folium.Marker([location_info["LAT"], location_info["LONG"]], popup=location_info["NM_MUNICIPIO"]))




# Adiciona as camadas ao mapa
mapc.add_child(layer1)



# Adiciona o controle de camdas ao mapa
folium.LayerControl().add_to(mapc)

# %%
mapc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e04416bf21a250e43e78f5fa38746e72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e04416bf21a250e43e78f5fa38746e72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e04416bf21a250e43e78f5fa38746e72 = L.map(
#                 &quot;map_e04416bf21a250e43e78f5fa38746e72&quot;,
#                 {
#                     center: [-14.067144574523127, -45.5448010707875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e04416bf21a250e43e78f5fa38746e72);
#
#
#
#
#
#             var tile_layer_c08b33b87e605a12400992b266855dd6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e04416bf21a250e43e78f5fa38746e72);
#
#
#             var feature_group_efe9973c2d93baf02a1b2b5fad4453c6 = L.featureGroup(
#                 {}
#             ).addTo(map_e04416bf21a250e43e78f5fa38746e72);
#
#
#             var marker_0436511ff845e8304f71227dedd2fe4b = L.marker(
#                 [-17.2070118719999, -39.2166885899999],
#                 {}
#             ).addTo(feature_group_efe9973c2d93baf02a1b2b5fad4453c6);
#
#
#         var popup_fd7b2b75c6e990b0b7f322d9ab019eb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61c393cd66f91a733bebc2d7d535a289 = $(`&lt;div id=&quot;html_61c393cd66f91a733bebc2d7d535a289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PRADO&lt;/div&gt;`)[0];
#                 popup_fd7b2b75c6e990b0b7f322d9ab019eb3.setContent(html_61c393cd66f91a733bebc2d7d535a289);
#
#
#
#         marker_0436511ff845e8304f71227dedd2fe4b.bindPopup(popup_fd7b2b75c6e990b0b7f322d9ab019eb3)
#         ;
#
#
#
#
#             var marker_7e8942b2318478af1d318f42f9a4a26d = L.marker(
#                 [-13.27150802046, -40.0143508075563],
#                 {}
#             ).addTo(feature_group_efe9973c2d93baf02a1b2b5fad4453c6);
#
#
#         var popup_535c67f4f696c6beb8c0d672ba092e16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4559a2496db6a6785a96da30756d86e9 = $(`&lt;div id=&quot;html_4559a2496db6a6785a96da30756d86e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IRAJUBA&lt;/div&gt;`)[0];
#                 popup_535c67f4f696c6beb8c0d672ba092e16.setContent(html_4559a2496db6a6785a96da30756d86e9);
#
#
#
#         marker_7e8942b2318478af1d318f42f9a4a26d.bindPopup(popup_535c67f4f696c6beb8c0d672ba092e16)
#         ;
#
#
#
#
#             var marker_fe7c635c35b4e22c67d9be79fd226879 = L.marker(
#                 [-26.6740363576998, -52.170085224814],
#                 {}
#             ).addTo(feature_group_efe9973c2d93baf02a1b2b5fad4453c6);
#
#
#         var popup_bb07def444d1a8673b0b63294d786415 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1129c8afe1b0a4ce9cebc0b511afcdb9 = $(`&lt;div id=&quot;html_1129c8afe1b0a4ce9cebc0b511afcdb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABELARDO LUZ&lt;/div&gt;`)[0];
#                 popup_bb07def444d1a8673b0b63294d786415.setContent(html_1129c8afe1b0a4ce9cebc0b511afcdb9);
#
#
#
#         marker_fe7c635c35b4e22c67d9be79fd226879.bindPopup(popup_bb07def444d1a8673b0b63294d786415)
#         ;
#
#
#
#
#             var marker_aeb81f35ab309023a6051b0f769c3e50 = L.marker(
#                 [-15.8930719264003, -49.4989724648244],
#                 {}
#             ).addTo(feature_group_efe9973c2d93baf02a1b2b5fad4453c6);
#
#
#         var popup_663a33e11a292c62e66fae407dcd0c3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5090ece85692e5b50d541272d6a29797 = $(`&lt;div id=&quot;html_5090ece85692e5b50d541272d6a29797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JARAGUÁ&lt;/div&gt;`)[0];
#                 popup_663a33e11a292c62e66fae407dcd0c3e.setContent(html_5090ece85692e5b50d541272d6a29797);
#
#
#
#         marker_aeb81f35ab309023a6051b0f769c3e50.bindPopup(popup_663a33e11a292c62e66fae407dcd0c3e)
#         ;
#
#
#
#
#             var marker_1f153eae8cabb408674f3990e15ceb48 = L.marker(
#                 [-8.80525639458382, -35.88024249535],
#                 {}
#             ).addTo(feature_group_efe9973c2d93baf02a1b2b5fad4453c6);
#
#
#         var popup_168dbdeeccf1e489a63d712a7303f861 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef5ab6a5a2a8aa83d058279680da8ae7 = $(`&lt;div id=&quot;html_ef5ab6a5a2a8aa83d058279680da8ae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SÃO BENEDITO DO SUL&lt;/div&gt;`)[0];

# %%
mapc.save("mapa_camadas.html")
